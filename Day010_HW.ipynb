# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
# '''
# Your Code
# '''
# !pip install grab --ignore-installed pycurl
# Out:
# Collecting grab
#   Downloading https://files.pythonhosted.org/packages/26/87/c0b939da311bed38c0c073fd61675cfbe4ba585c2a04370a5b7e106a2639/grab-0.6.41.tar.gz (1.1MB)
# Collecting pycurl
#   Downloading https://files.pythonhosted.org/packages/b9/21/7b0db498334b552094dc72960fb2e528699952c953652b585f0b3dd88c79/pycurl-7.43.0.5-cp37-cp37m-win_amd64.whl (1.7MB)
# Collecting weblib>=0.1.28 (from grab)
#   Downloading https://files.pythonhosted.org/packages/67/16/2761dab6e8515708a2762dc34e6b8e089df21211d98f91d298911f2fd5b0/weblib-0.1.30.tar.gz
# Collecting six (from grab)
#   Downloading https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting user_agent (from grab)
#   Downloading https://files.pythonhosted.org/packages/c3/ca/15546284f62edfec7666ecb6403a6e77f5db850def37cd36f140d99cce02/user_agent-0.1.9.tar.gz
# Collecting selection (from grab)
#   Downloading https://files.pythonhosted.org/packages/32/01/7e9f093e502c3b19d8fd8c7046de31534a0254bb6aaced0403739dc7f704/selection-0.0.14.tar.gz
# Collecting defusedxml (from grab)
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting pytils (from weblib>=0.1.28->grab)
#   Downloading https://files.pythonhosted.org/packages/c6/c1/12b556b5bb393ce5130d57af862d045f57fee764797c0fe837e49cb2a5da/pytils-0.3.tar.gz (89kB)
# Building wheels for collected packages: grab, weblib, user-agent, selection, pytils
#   Building wheel for grab (setup.py): started
#   Building wheel for grab (setup.py): finished with status 'done'
#   Created wheel for grab: filename=grab-0.6.41-cp37-none-any.whl size=84701 sha256=c933b4d3573f1e7c5aae76d260f1c8cb5bffbb12077334ac3fe6c53a085adfa0
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\84\ff\2d\08f71c11e5b73027dfa7d1ac8bd654b60af2df57ae89bd29d5
#   Building wheel for weblib (setup.py): started
#   Building wheel for weblib (setup.py): finished with status 'done'
#   Created wheel for weblib: filename=weblib-0.1.30-cp37-none-any.whl size=40161 sha256=8f67783cf3e78eb988b9365e47b9cb7066df433e0744e1c6d12a6b49eeeedaa0
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\4d\92\d1\f89cbbefae35442b82a069a60f6b596c77f22ab5d58813e4a4
#   Building wheel for user-agent (setup.py): started
#   Building wheel for user-agent (setup.py): finished with status 'done'
#   Created wheel for user-agent: filename=user_agent-0.1.9-cp37-none-any.whl size=18812 sha256=ff8dc97528e88f71b3c1ba34d938e56acc300ddcedd7dfeb996d2f8ad6f959f2
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\92\80\3f\5d79277825042f2d4d447f594e3fc046f1e506f2b481d364b2
#   Building wheel for selection (setup.py): started
#   Building wheel for selection (setup.py): finished with status 'done'
#   Created wheel for selection: filename=selection-0.0.14-cp37-none-any.whl size=5365 sha256=7020ed53505d14e5fa5c1c1373db404c5060968597629dc12abc5e0bb8f79648
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\f6\78\ea\df9f78c9f3fb643b9fc9f6e70fab990e5f8455024d34019418
#   Building wheel for pytils (setup.py): started
#   Building wheel for pytils (setup.py): finished with status 'done'
#   Created wheel for pytils: filename=pytils-0.3-cp37-none-any.whl size=40360 sha256=fab6a2b5efb13242a415a119b984cc9c57ad3cd9d699908c9e15ddf77fbc4852
#   Stored in directory: C:\Users\USER\AppData\Local\pip\Cache\wheels\d6\f9\dc\4f07d8ee40d9cfca9973b3f4aeff99d0bb69900e5f3dffbf32
# Successfully built grab weblib user-agent selection pytils
# Installing collected packages: pytils, six, user-agent, weblib, selection, defusedxml, grab, pycurl
# ERROR: astroid 2.3.1 requires typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8", which is not installed.
# ERROR: astroid 2.3.1 has requirement six==1.12, but you'll have six 1.14.0 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] 存取被拒。: 'C:\\ProgramData\\Anaconda3\\Lib\\site-packages\\six.py'
# Consider using the `--user` option or check the permissions.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.dcard.tw/f'
r = requests.get(url)
r.encoding = 'utf-8'
soup = BeautifulSoup(r.text)


print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><link href="https://fonts.googleapis.com/css?family=Roboto:400,300" rel="stylesheet" type="text/css"/><meta content="Dcard" name="application-name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="Dcard" property="al:ios:app_name"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><meta content="Dcard" property="al:android:app_name"/><link href="/_next/static/manifest.json" rel="manifest"/><link href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/><link href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/><link href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');</script><meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/><meta charset="utf-8"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/><meta content="website" property="og:type"/><meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/><meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image"/><meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/><meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/><title>Dcard</title><link href="https://www.dcard.tw/f" rel="canonical"/><meta content="https://www.dcard.tw/f" itemprop="url" name="url"/><meta content="Dcard" property="og:site_name"/><meta content="Dcard" property="og:title"/><meta content="https://www.dcard.tw/f" property="og:url"/><meta content="Dcard" property="twitter:title"/><meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/><meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:ios:url"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}</script><meta content="21" name="next-head-count"/><link as="style" href="/_next/static/css/6d1bbc10820647a103b8.css" rel="preload"/><link href="/_next/static/css/6d1bbc10820647a103b8.css" rel="stylesheet"/><link as="script" href="/_next/static/cOKVafdWrjLqqc_kERlyw/pages/forum.js" rel="preload"/><link as="script" href="/_next/static/cOKVafdWrjLqqc_kERlyw/pages/_app.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.eacc63218ddc09a8a678.js" rel="preload"/><link as="script" href="/_next/static/chunks/ea9ab151e4bcf2e1335b0cafa486406aecb63299.1c70ee4e6ed1f53d7728.js" rel="preload"/><link as="script" href="/_next/static/chunks/b5804ca5076ae63cb3bcb206ae9a64d88a9b0719.0bc2fae3947b9ba44993.js" rel="preload"/><link as="script" href="/_next/static/chunks/1047ad127e94bfe674e16b4af0419c73891e0b9f.973fcdc6f3c8b3c0637e.js" rel="preload"/><link as="script" href="/_next/static/chunks/88.1fe916e4e34a1be77445.js" rel="preload"/><link as="script" href="/_next/static/chunks/2fa7336a6f5d5372d9f1f5fa72bf98d34a712228.34a29932472c6f32eb61.js" rel="preload"/><link as="script" href="/_next/static/chunks/f54b42984bfe4d114461fcea2710af414ac1fe74.05575417ca7aea999f9a.js" rel="preload"/><link as="script" href="/_next/static/chunks/98.3f9793e7b676dafcac65.js" rel="preload"/><link as="script" href="/_next/static/chunks/035c3a5dbce655498ebf426080fef9033b4583db.1b1271e70a5f317ecae1.js" rel="preload"/><link as="script" href="/_next/static/chunks/115.5fc8a7c2187f4dd2fd38.js" rel="preload"/><link as="script" href="/_next/static/chunks/219da9e2f6bee497e1c4cec0dfad8c986d15b5bf.f5b512c169583859b748.js" rel="preload"/><link as="script" href="/_next/static/chunks/64be282ec75c908b39f0eb579744e573e1b3ca0c.565292515ded3faad020.js" rel="preload"/><link as="script" href="/_next/static/chunks/102.b0e419a0a75b310a0f25.js" rel="preload"/><link as="script" href="/_next/static/chunks/1835cc11f68d6aec22cfb267be8a8f834b4baf7d.cff47e2afb4b09e017dd.js" rel="preload"/><link as="script" href="/_next/static/chunks/35e5ca1e52644a27865d4bf6b6bcf6934b01c37e.8c6d965871f46282f347.js" rel="preload"/><link as="script" href="/_next/static/chunk ...
# /* sc-component-id: sc-global-1522344194 */
# body{background-color:#00324e;}
# /* sc-component-id: ksi2hf-0 */
# .eNbBFe{display:none;}
# /* sc-component-id: ydgdj7-0 */
# .hhSnba{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .hhSnba img,.hhSnba svg{height:100%;width:100%;}.gCQlMD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:26px;height:26px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gCQlMD img,.gCQlMD svg{height:100%;width:100%;}.iYfIzd{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iYfIzd img,.iYfIzd svg{height:100%;width:100%;}.jkPESf{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:40px;height:40px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .jkPESf img,.jkPESf svg{height:100%;width:100%;}.cbhXy{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .cbhXy img,.cbhXy svg{height:100%;width:100%;}.iUPhXV{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:28px;height:28px;fill:#c4c4c4;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iUPhXV img,.iUPhXV svg{height:100%;width:100%;}.gRIdVl{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .gRIdVl img,.gRIdVl svg{height:100%;width:100%;}.ieFmwo{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:16px;height:16px;fill:rgba(0,0,0,.6);stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .ieFmwo img,.ieFmwo svg{height:100%;width:100%;}.joALQw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#3397cf;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .joALQw img,.joALQw svg{height:100%;width:100%;}.iLWWtS{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:18px;height:18px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .iLWWtS img,.iLWWtS svg{height:100%;width:100%;}.bwTNRH{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:44px;height:44px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);} .bwTNRH img,.bwTNRH svg{height:100%;width:100%;}.bVLqqa{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:21px;height:21px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}  ...
# /* sc-component-id: sc-1ag928-0 */
# .kUMklR{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;outline:none;font-size:16px;line-height:normal;border-radius:4px;padding:0 10px;height:40px;width:100%;-webkit-flex:1;-ms-flex:1;flex:1;color:rgba(0,0,0,.85);border:1px solid rgba(0,0,0,0.25);} .kUMklR::-webkit-input-placeholder{color:#c1c2c5;} .kUMklR::-moz-placeholder{color:#c1c2c5;} .kUMklR:-ms-input-placeholder{color:#c1c2c5;} .kUMklR::placeholder{color:#c1c2c5;}
# /* sc-component-id: pw4e6a-0 */
# .ierzKU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .ierzKU form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}.dODGjA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;} .dODGjA form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:rgb(238,238,238);border-radius:4px;overflow:hidden;width:100%;}
# /* sc-component-id: pw4e6a-1 */
# .fWARvU{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:14px;color:#fff;}.bkAvTt{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;font-size:16px;}
# /* sc-component-id: pw4e6a-2 */
# .jMlptb{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}
# /* sc-component-id: pw4e6a-3 */
# .elZfHj{padding-left:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: pw4e6a-4 */
# .copHwd{padding:0 2px;}
# /* sc-component-id: sc-1divb7s-0 */
# .jGSaFz{position:-webkit-sticky;position:sticky;top:48px;background:#fff;border-bottom:1px solid #dedede;padding:0 16px;z-index:10;}.kkFyqs{position:-webkit-sticky;position:sticky;top:60px;background:#fafafa;border-bottom:1px solid #dedede;padding:0 60px;z-index:10;}
# /* sc-component-id: sc-1divb7s-1 */
# .jgHqud{padding-top:10px;}
# /* sc-component-id: sc-1divb7s-2 */
# .fvImY{height:40px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1divb7s-3 */
# .jqcDIF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1divb7s-4 */
# .iXnhSl{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .iXnhSl:first-child{padding-left:0;} .iXnhSl a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .iXnhSl a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.glFNEP{height:100%;white-space:nowrap;-webkit-flex:1;-ms-flex:1;flex:1;} .glFNEP:first-child{padding-left:0;} .glFNEP a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 0px;} .glFNEP a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}.kQMWIM{height:100%;white-space:nowrap;} .kQMWIM:first-child{padding-left:0;} .kQMWIM a{color:#3397cf;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .kQMWIM a::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}.eOmoiY{height:100%;white-space:nowrap;} .eOmoiY:first-child{padding-left:0;} .eOmoiY a{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;position:relative;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;padding:20px 20px;} .eOmoiY a::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}
# /* sc-component-id: r0dumd-0 */
# .hraxjl{position:fixed;top:60px;right:25px;z-index:1000;}.eZbqml{position:fixed;bottom:33px;left:50%;right:50%;width:100vw;z-index:1000;}
# /* sc-component-id: sc-84v443-0 */
# .jAlbWa{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .jAlbWa:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .jAlbWa:hover{background:#006aa6;}.kgcVsA{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .kgcVsA:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.kGxGfT{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #fff;color:#fff;background:transparent;} .kGxGfT:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.iIxOaU{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:none;opacity:0.5;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .iIxOaU:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .iIxOaU:hover{background:#006aa6;}.bcPQqz{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:none;opacity:0.5;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:none;background:#3397cf;color:#fff;} .bcPQqz:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);}.eSJmXu{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:13px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #c1c2c5;background:#fff;color:rgba(0,0,0,.6);} .eSJmXu:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .eSJmXu:active{box-shadow:inset 0 1px 2px 0 rgba(0,0,0,0.3);}.fXqGIR{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;white-space:nowrap;border-radius:4px;font-size:14px;padding:0 16px;height:37px;pointer-events:all;opacity:1;-webkit-transition:all 0.15s cubic-bezier(.4,0,.2,1);transition:all 0.15s cubic-bezier(.4,0,.2,1);border:1px solid #3397cf;color:#006aa6;background:#fff;} .fXqGIR:active{box-shadow:inset 0 2px 2px 0 rgba(0,0,0,0.3);} .fXqGIR:hover{background:#efefef;}.kUHSsi{display:inline-block;position:relative;outline:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user- ...
# /* sc-component-id: avchkw-0 */
# .lcIqKn{display:grid;max-width:1280px;margin:auto;padding:60px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}
# /* sc-component-id: avchkw-1 */
# .dLkKRc{grid-column:start / mainLeft;}
# /* sc-component-id: avchkw-2 */
# .ciNPhh{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}.hpsGZq{min-width:calc(undefinedpx + 0px);grid-column:mainLeft / mainRight;}
# /* sc-component-id: avchkw-3 */
# .kIHllc{grid-column:mainRight / end;}
# /* sc-component-id: sc-17vj83f-0 */
# .iJCqeQ{margin:0 12px;min-height:calc(100vh - 80px);min-width:728px;padding-top:20px;height:100%;}.kqKnyl{-webkit-flex:1;-ms-flex:1;flex:1;margin:0 0px;min-height:calc(100vh - 48px);min-width:0px;padding-top:0px;height:100%;}
# /* sc-component-id: sc-17vj83f-1 */
# .hSVvaC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-top:0px;}
# /* sc-component-id: sc-17vj83f-2 */
# .nlkop{height:100%;background:#fafafa;border-radius:4px 4px 0 0;}
# /* sc-component-id: sc-1hbn6e7-0 */
# .cAUXkt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;text-align:center;padding:50px 0;}
# /* sc-component-id: sc-1hbn6e7-1 */
# .dagORX{display:block;width:250px;margin-bottom:30px;}
# /* sc-component-id: sc-1hbn6e7-2 */
# .fIvJvb{font-size:30px;font-weight:400;line-height:42px;margin-bottom:10px;}
# /* sc-component-id: sc-1hbn6e7-3 */
# .dARMVx{color:rgba(0,0,0,.45);font-size:18px;line-height:30px;max-width:45%;}
# /* sc-component-id: cagncm-0 */
# .heuwav{position:relative;}
# /* sc-component-id: cagncm-1 */
# .LDAeQ{visibility:hidden;padding-top:calc(100% / 1.7777777777777777);pointer-events:none;}.bOYByu{visibility:hidden;padding-top:calc(100% / 0.5625);pointer-events:none;}.bjdYUu{visibility:hidden;padding-top:calc(100% / 0.5624999999999993);pointer-events:none;}.jkGRpF{visibility:hidden;padding-top:calc(100% / 0.8);pointer-events:none;}.jIVHRC{visibility:hidden;padding-top:calc(100% / 1);pointer-events:none;}.fMTeMY{visibility:hidden;padding-top:calc(100% / 1.7391304347826089);pointer-events:none;}.kzfyvZ{visibility:hidden;padding-top:calc(100% / 2.162162162162162);pointer-events:none;}.dOkRgV{visibility:hidden;padding-top:calc(100% / 1.3333333333333333);pointer-events:none;}.jNwtlj{visibility:hidden;padding-top:calc(100% / 0.75);pointer-events:none;}.BvtQj{visibility:hidden;padding-top:calc(100% / 0.46153846153846156);pointer-events:none;}.keNDr{visibility:hidden;padding-top:calc(100% / 0.4768211920529801);pointer-events:none;}.cTRxep{visibility:hidden;padding-top:calc(100% / 1.3008130081300813);pointer-events:none;}.iOzsDO{visibility:hidden;padding-top:calc(100% / 1.775);pointer-events:none;}.fJtwvR{visibility:hidden;padding-top:calc(100% / 0.5660377358490566);pointer-events:none;}.gqgmhE{visibility:hidden;padding-top:calc(100% / 0.5633802816901409);pointer-events:none;}.jVNDlw{visibility:hidden;padding-top:calc(100% / 0.5);pointer-events:none;}.jeIltF{visibility:hidden;padding-top:calc(100% / 0.5357142857142857);pointer-events:none;}.dNlAQx{visibility:hidden;padding-top:calc(100% / 2.1666666666666665);pointer-events:none;}.dOjssS{visibility:hidden;padding-top:calc(100% / 0.503125);pointer-events:none;}.hjUALt{visibility:hidden;padding-top:calc(100% / 0.46249999999999997);pointer-events:none;}.fKRBfF{visibility:hidden;padding-top:calc(100% / 0.5333333333333333);pointer-events:none;}.gPynV{visibility:hidden;padding-top:calc(100% / 1.3274336283185841);pointer-events:none;}.kOuKtY{visibility:hidden;padding-top:calc(100% / 0.5298013245033113);pointer-events:none;}.cUVfBO{visibility:hidden;padding-top:calc(100% / 2);pointer-events:none;}
# /* sc-component-id: cagncm-2 */
# .fNGJuR{position:absolute;left:0;top:0;right:0;bottom:0;}
# /* sc-component-id: sc-1ist1s2-0 */
# .cRUrbl{width:100%;}
# /* sc-component-id: jo1zdl-0 */
# .rCmLK{background:#fff;box-shadow:rgba(0,0,0,0.05) 0px 4px 4px 0px,rgba(0,0,0,0.15) 0px 0px 4px 0px;position:absolute;top:50%;left:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);border-radius:4px;height:px;width:px;min-width:90%;max-width:calc(100vw - 48px);min-height:0;max-height:calc(100% - 48px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:left;}
# /* sc-component-id: jo1zdl-1 */
# .dJUxnG{padding:24px 24px 10px;}
# /* sc-component-id: jo1zdl-2 */
# .cTNmGN{position:relative;}
# /* sc-component-id: jo1zdl-3 */
# .iMYeMt{font-size:24px;font-size:20px;font-weight:700;line-height:24px;color:rgba(0,0,0,.85);text-align:left;}
# /* sc-component-id: jo1zdl-4 */
# .keinQf{padding:0 24px;color:rgba(0,0,0,.8);font-size:13px;line-height:1.4;}
# /* sc-component-id: jo1zdl-7 */
# .kzOwDl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1;-ms-flex:1;flex:1;overflow-y:auto;min-height:0;} .kzOwDl:nth-child(2) > div{padding-top:0;}
# /* sc-component-id: jo1zdl-8 */
# .ifDwvY{-webkit-flex:1;-ms-flex:1;flex:1;height:100%;padding:20px 24px 24px;}
# /* sc-component-id: sc-8dk2q5-1 */
# .iCflnd{min-height:0;-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-8dk2q5-2 */
# .gpTxIH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;margin-top:20px;} .gpTxIH:first-child{margin-top:0;}
# /* sc-component-id: sc-8dk2q5-3 */
# .cuDCyD{margin-left:20px;} .cuDCyD:first-child{margin-left:0;width:100%;}.iGgriV{margin-left:20px;} .iGgriV:first-child{margin-left:0;}
# /* sc-component-id: sc-1ykc0nb-2 */
# .iNRVSl{display:inline-block;height:100%;}
# /* sc-component-id: rry249-0 */
# .eEHQqz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:32px;color:rgba(0,0,0,.6);font-size:14px;border-radius:4px;background:#efefef;padding:0 16px;white-space:nowrap;}.hXxAcg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:32px;color:rgba(0,0,0,.6);font-size:13px;border-radius:4px;background:#efefef;padding:0 16px;white-space:nowrap;}
# /* sc-component-id: sc-1285qe-0 */
# .fnbysa{overflow-y:hidden;}
# /* sc-component-id: sc-1285qe-1 */
# .frGOVM{overflow-x:auto;overflow-y:hidden;}
# /* sc-component-id: sc-1285qe-2 */
# .kwyXwr{white-space:nowrap;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:64px;padding:0 0px;} .kwyXwr::after{content:'';-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;height:64px;width:0px;}
# /* sc-component-id: sc-1285qe-3 */
# .Gmrxn{display:block;}
# /* sc-component-id: sc-1285qe-4 */
# .cRztcx{display:inline-block;padding-right:8px;padding-top:8px;} .cRztcx:last-child{padding-right:0;}.jMCMEQ{display:inline-block;padding-right:16px;padding-top:16px;} .jMCMEQ:last-child{padding-right:0;}.kixOiI{display:inline-block;padding-right:16px;padding-top:px;} .kixOiI:last-child{padding-right:0;}
# /* sc-component-id: uzae24-0 */
# .eSWhfz{width:100%;height:100%;position:relative;background:#000;}
# /* sc-component-id: uzae24-1 */
# .Fzfdz{position:absolute;top:0;left:0;width:100%;height:100%;}
# /* sc-component-id: cgkbr-0 */
# .dVbdRN{border:0;width:100%;}
# /* sc-component-id: sc-1n5ks60-0 */
# .bLpAcs{background-color:rgb(250,250,250);padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}.ljZaZc{background-color:#fff;padding:20px 0 16px 0;border-bottom:1px solid #d9d9d9;}
# /* sc-component-id: sc-1n5ks60-1 */
# .gUkFib{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.5);font-size:14px;margin-bottom:14px;}
# /* sc-component-id: sc-1n5ks60-2 */
# .gLEJWb{background-color:#f0b941;padding:2px 4px;border-radius:4px;color:#fff;margin-right:10px;}.gpGROt{background-color:rgba(0,0,0,0.35);padding:2px 4px;border-radius:4px;color:#fff;margin-right:10px;}
# /* sc-component-id: sc-1n5ks60-3 */
# .gsITcD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;color:rgba(0,0,0,.5);font-size:14px;line-height:1;}
# /* sc-component-id: sc-1n5ks60-4 */
# .eEnMxW{color:#f0b941;font-weight:bold;font-size:28px;margin-right:10px;}
# /* sc-component-id: sc-1n5ks60-5 */
# .hBQCmL{-webkit-text-decoration-line:line-through;text-decoration-line:line-through;}
# /* sc-component-id: sc-1aui6l1-0 */
# .iFXkqk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: sc-1aui6l1-1 */
# .kyLyek{border:none;background:#a8a8a8;width:12px;height:12px;border-radius:50%;margin:0 8px;padding:0;cursor:pointer;outline:none;}.bxUwdt{border:none;background:rgba(168,168,168,0.3);width:12px;height:12px;border-radius:50%;margin:0 8px;padding:0;cursor:pointer;outline:none;}
# /* sc-component-id: sc-1v5l8ro-0 */
# .cboeuQ{position:relative;}
# /* sc-component-id: sc-1v5l8ro-2 */
# .jTdrJK{border:none;background:none;position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);opacity:0;cursor:pointer;outline:none;padding:0;left:20px;} .sc-1v5l8ro-0:hover .jTdrJK{opacity:1;}
# /* sc-component-id: sc-1v5l8ro-3 */
# .htnUjJ{border:none;background:none;position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);opacity:0;cursor:pointer;outline:none;padding:0;right:20px;} .sc-1v5l8ro-0:hover .htnUjJ{opacity:1;}
# /* sc-component-id: sc-1v5l8ro-5 */
# .iCmpce{position:absolute;bottom:12px;left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);}
# /* sc-component-id: sc-1xsathd-0 */
# .frmeSE{width:100%;height:calc((728px - 120px) * (3 / 4));background-size:cover;background-position:center center;background-repeat:no-repeat;}.fFVWmP{width:100%;height:calc((100vw - 32px) * (3 / 4));background-size:cover;background-position:center center;background-repeat:no-repeat;}
# /* sc-component-id: sc-13e2k1-0 */
# .bAfPQq{margin:20px 0;}
# /* sc-component-id: kfwtwu-0 */
# .plPAm{position:relative;height:120px;padding:16px 0;width:100%;}.jxylh{position:relative;height:64px;padding:13px 0;width:100%;}
# /* sc-component-id: w1s81u-0 */
# .ghccAs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:8px 0 6px;padding:0 10px;border:1px solid rgb(233,233,233);border-radius:4px;background:#fff;box-shadow:0 1px 2px #ddd;line-height:1.3;max-width:430px;width:100%;min-height:65px;overflow:hidden;}
# /* sc-component-id: w1s81u-1 */
# .jyJcRR{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: w1s81u-2 */
# .cKxtrZ{margin-right:10px;border-radius:3px;overflow:hidden;background-color:#006aa6;}.dykAcs{margin-right:10px;border-radius:3px;padding:5px;overflow:hidden;background-color:#006aa6;}
# /* sc-component-id: w1s81u-3 */
# .feAVOA{-webkit-flex:1;-ms-flex:1;flex:1;min-width:0;}
# /* sc-component-id: w1s81u-4 */
# .MWKTC{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:16px;font-weight:bold;line-height:1.3;color:rgba(0,0,0,.85);padding-bottom:5px;}
# /* sc-component-id: w1s81u-5 */
# .hBEhsQ{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;font-size:14px;color:rgba(0,0,0,.35);line-height:16px;height:16px;}
# /* sc-component-id: xt0n8u-0 */
# .loyxor{border:0;}
# /* sc-component-id: omlszd-0 */
# .bbxbmN{border:0;height:100%;width:100%;}
# /* sc-component-id: sc-5aa8ap-0 */
# .gpeOcj{border:0;height:100%;width:100%;}
# /* sc-component-id: sc-1r4us9h-0 */
# .gLRgot{overflow:hidden;position:relative;max-width:100%;max-height:60vh;}.cDOlbF{overflow:hidden;position:relative;max-width:100%;max-height:vh;}
# /* sc-component-id: sc-1r4us9h-1 */
# .hTuwCj{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;}.cuCQeX{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}
# /* sc-component-id: sc-1r4us9h-2 */
# .jzwjYE{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;position:absolute;top:0;left:0;}.bvlcaJ{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:vh;position:absolute;top:0;left:0;}
# /* sc-component-id: sc-1eso38c-0 */
# .lLnjb{margin:10px 0;}
# /* sc-component-id: hmo708-0 */
# .dkyZPk{white-space:pre-wrap;}
# /* sc-component-id: sc-1ro4bpk-0 */
# .jXIcFN{font-size:18px;line-height:1.6;word-wrap:break-word;}.jKdblb{font-size:15px;color:rgba(0,0,0,.6);line-height:1.6;word-wrap:break-word;}
# /* sc-component-id: sc-1ro4bpk-1 */
# .bNRMtc{padding-bottom:16px;}.eTxtzv{padding-bottom:22px;}
# /* sc-component-id: sc-1ro4bpk-2 */
# .aEXNq{padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1ro4bpk-3 */
# .fMLUtJ{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}.hPNbBN{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);padding-bottom:3px;}
# /* sc-component-id: sc-116rzs1-0 */
# .hzTqOV{font-size:30px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}.dYEYmA{font-size:19px;line-height:1.5;font-weight:500;word-wrap:break-word;color:rgba(0,0,0,.95);}
# /* sc-component-id: cra5e8-0 */
# .gpDnCL{border-radius:50%;overflow:hidden;}
# /* sc-component-id: cra5e8-1 */
# .hbaYDn{background:#2490bf;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.fYHPhX{background:#cb3a6b;color:#fff;font-size:25.6px;height:40px;width:40px;line-height:40px;text-align:center;border-radius:50%;}.hAyDgJ{background:#cb3a6b;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.fPjsad{background:#2490bf;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}.iVFhUp{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.dLdNOh{background:#cb3a6b;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.eiVDLb{background:#2490bf;color:#fff;font-size:64px;height:100px;width:100px;line-height:100px;text-align:center;border-radius:50%;}.buwgzc{background:#2490bf;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}.ehIwJk{background:#cb3a6b;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}.ldnNRb{background:#2490bf;color:#fff;font-size:30.72px;height:48px;width:48px;line-height:48px;text-align:center;border-radius:50%;}
# /* sc-component-id: cra5e8-2 */
# .ksDGRc{display:block;border-radius:50%;object-fit:cover;}
# /* sc-component-id: ulutkk-0 */
# .bdZmTC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}.iKgfXR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}
# /* sc-component-id: ulutkk-1 */
# .iUvXkY{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: ulutkk-2 */
# .hXoZkZ{color:rgba(0,0,0,.6);} .hXoZkZ:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: ulutkk-3 */
# .bWuoYI{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}
# /* sc-component-id: ulutkk-5 */
# .hCitbx{background-color:#a3a3a3;color:#fff;font-size:12px;padding:3px 4px;border-radius:4px;margin-left:8px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: ulutkk-6 */
# .eUUiOP{margin-left:3px;}
# /* sc-component-id: ulutkk-7 */
# .gFxUyu{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}
# /* sc-component-id: sc-1dy4jrl-0 */
# .dGuoO{padding:16px;border:1px solid rgb(233,233,233);border-radius:4px;}
# /* sc-component-id: sc-1dy4jrl-1 */
# .hSudgn{font-size:14px;padding-bottom:8px;}
# /* sc-component-id: sc-1dy4jrl-2 */
# .hLhSKT{font-size:18px;color:rgba(0,0,0,.85);font-weight:normal;padding-bottom:8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1dy4jrl-3 */
# .cChNNo{padding:12px 0 22px;}.cHbQxZ{padding:12px 0 16px;}
# /* sc-component-id: sc-1dy4jrl-4 */
# .gdhcYM{font-size:14px;color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: sc-1dy4jrl-5 */
# .VJRLs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:rgba(0,0,0,.35);padding-top:50px;}
# /* sc-component-id: sc-1dy4jrl-6 */
# .kogORL:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: sc-4gkg5b-0 */
# .kuUoxV{position:absolute;background:rgb(30,30,30);border-radius:4px;z-index:10;left:calc(100% + 5px + 8px);top:50%;-webkit-transform:translateY(calc(0px - 50%));-ms-transform:translateY(calc(0px - 50%));transform:translateY(calc(0px - 50%));width:auto;border-radius:0;}.jNSdZG{position:absolute;background:rgb(30,30,30);border-radius:4px;z-index:10;left:calc(100% + 5px + 8px);top:50%;-webkit-transform:translateY(calc(0px - 50%));-ms-transform:translateY(calc(0px - 50%));transform:translateY(calc(0px - 50%));}
# /* sc-component-id: sc-4gkg5b-1 */
# .hVlCDH{position:absolute;background:linear-gradient(-45deg,rgb(30,30,30) 55%,transparent 55%);height:10px;width:10px;z-index:10;left:calc(100% + 8px);top:50%;-webkit-transform:translate(0,-50%) rotateZ(135deg);-ms-transform:translate(0,-50%) rotateZ(135deg);transform:translate(0,-50%) rotateZ(135deg);box-shadow:none;}.hFiaOa{position:absolute;background:linear-gradient(-45deg,rgb(30,30,30) 55%,transparent 55%);height:10px;width:10px;z-index:10;left:calc(100% + 8px);top:50%;-webkit-transform:translate(0,-50%) rotateZ(135deg);-ms-transform:translate(0,-50%) rotateZ(135deg);transform:translate(0,-50%) rotateZ(135deg);}
# /* sc-component-id: mx40yw-0 */
# .bcJcFo{background:#fafafa;padding:0 60px 0;}.gHmUSp{background:#fff;padding:0 16px 0;}
# /* sc-component-id: mx40yw-1 */
# .buQRlc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:0px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.iGtQjR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-bottom:5px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: mx40yw-2 */
# .eJUhfX{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: mx40yw-3 */
# .jiGwao{font-size:14px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.lcBskY{font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: mx40yw-4 */
# .iMFwTN{color:rgba(0,0,0,.35);white-space:nowrap;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;} .iMFwTN:not(:last-child)::after{content:'·';padding:0 0.5em;}
# /* sc-component-id: mx40yw-5 */
# .iJnYGo{cursor:pointer;fill:#a8a8a8;} .iJnYGo:hover{fill:#595959;}
# /* sc-component-id: mx40yw-6 */
# .dTLUmr{padding:22px 0 40px;}.hldKBV{padding:16px 0 24px;}
# /* sc-component-id: mx40yw-7 */
# .kkMFCl{padding-bottom:16px;}.cMiHcM{padding-bottom:24px;}
# /* sc-component-id: sc-199taff-0 */
# .cecgEa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:12px;}
# /* sc-component-id: sc-199taff-1 */
# .imwAVu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:14px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;} .imwAVu:hover > *{fill:#ea5c5c;}.kVAWGS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgba(0,0,0,.35);font-size:13px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: sc-199taff-2 */
# .byDBmK{cursor:pointer;display:block;margin-right:14px;}.jQdHiY{cursor:pointer;display:block;margin-right:8px;}
# /* sc-component-id: sc-199taff-3 */
# .hUVsj{background:rgba(0,0,0,0.05);width:1px;height:24px;margin:0 8px 0 16px;}.gHZDSU{background:rgba(0,0,0,0.05);width:1px;height:16px;margin:0 2px 0 10px;}
# /* sc-component-id: sc-199taff-4 */
# .gYXlWv{cursor:pointer;} .gYXlWv:hover{fill:#3397cf;}
# /* sc-component-id: wpqo7k-0 */
# .kMCYaU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:16px;}.hmvoFh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:13px;}
# /* sc-component-id: wpqo7k-1 */
# .dyRjoS{padding-right:15px;}
# /* sc-component-id: wpqo7k-2 */
# .fAWpiS{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;}
# /* sc-component-id: wpqo7k-3 */
# .dNIZKT{color:rgba(0,0,0,.85);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: wpqo7k-4 */
# .kWqgmM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;color:rgba(0,0,0,.35);padding-top:3px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}
# /* sc-component-id: wpqo7k-5 */
# .fpNVYd{color:rgba(0,0,0,.35);}
# /* sc-component-id: wpqo7k-6 */
# .iitPqz{margin:0 0.5em;border-right:1px solid #dfdfdf;}
# /* sc-component-id: wpqo7k-7 */
# .eJGwQY{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;cursor:pointer;}
# /* sc-component-id: wpqo7k-8 */
# .jrtXBR{margin-left:3px;}
# /* sc-component-id: sc-1eyteeh-0 */
# .jEVzWj{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid rgb(233,233,233);position:relative;}.cuEcOa{color:rgba(0,0,0,.85);font-size:18px;padding:16px 0;border-bottom:1px solid transparent;position:relative;}.bsYdqe{color:rgba(0,0,0,.85);font-size:18px;padding:26px 30px;border-bottom:1px solid transparent;position:relative;}.gdmrGU{color:rgba(0,0,0,.85);font-size:18px;padding:26px 20px;border-bottom:1px solid transparent;position:relative;}
# /* sc-component-id: sc-1eyteeh-1 */
# .dOyvWD{margin-top:20px;padding:10px 0;border-top:1px solid rgb(233,233,233);border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: sc-1eyteeh-2 */
# .eSChfC{font-size:16px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}.bTcUk{font-size:13px;line-height:30px;color:rgba(0,0,0,.35);margin-bottom:3px;}
# /* sc-component-id: sc-1eyteeh-3 */
# .TPgVx{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .TPgVx .sc-1r4us9h-0 > img{height:25vh;}.bdyeVL{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .bdyeVL .sc-1r4us9h-0 > img{height:25vh;}.bBfeqi{color:rgba(0,0,0,.85);font-size:18px;line-height:1.6;padding-top:24px;word-break:break-all;} .bBfeqi .sc-1r4us9h-0 > img{height:initial;}.kjEfMP{color:rgba(0,0,0,.6);font-size:15px;line-height:1.6;padding-top:16px;word-break:break-all;} .kjEfMP .sc-1r4us9h-0 > img{height:initial;}
# /* sc-component-id: sc-1h0od67-0 */
# .feAeEX{border-bottom:1px solid rgb(233,233,233);border-top:1px solid rgb(233,233,233);cursor:pointer;position:relative;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: sc-1h0od67-1 */
# .kdswce{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:#3397cf;padding:24px 0;font-size:14px;} .kdswce:hover{background:#efefef;}
# /* sc-component-id: sc-1h0od67-2 */
# .iJQDuK{margin-right:10px;-webkit-transform:rotateZ();-ms-transform:rotateZ();transform:rotateZ();}
# /* sc-component-id: sc-1h0od67-3 */
# .jdGHRb{position:absolute;bottom:calc(50% + 50vh);pointer-events:none;visibility:hidden;}
# /* sc-component-id: b7opi3-0 */
# .dlPWaY{padding:0 60px;}.BwuPj{padding:0 16px;}
# /* sc-component-id: b7opi3-1 */
# .byxsrh{border-bottom:1px solid rgb(233,233,233);padding:2px 0;color:rgba(0,0,0,.35);font-size:16px;font-weight:400;}.dSegVb{border-bottom:1px solid rgba(0,0,0,0.05);padding:12px 0;color:rgba(0,0,0,.35);font-size:13px;font-weight:400;}
# /* sc-component-id: sc-193jsz9-0 */
# .vDKIy{padding:0 60px;}.kTnPum{padding:0 16px;}
# /* sc-component-id: sc-193jsz9-1 */
# .cYhtHG{background:#fff;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px 0;border-bottom:1px solid rgb(233,233,233);}.ePHxKd{background:#fafafa;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-bottom:1px solid rgb(233,233,233);}
# /* sc-component-id: x0lsoh-0 */
# .fCbVDL{background:#f5f5f5;padding:0 60px;padding-bottom:120px;}
# /* sc-component-id: x0lsoh-1 */
# .fRNXlA{border-top:1px solid rgb(233,233,233);padding:24px 0;}.fQRmbe{border-top:1px solid transparent;padding:24px 0;}
# /* sc-component-id: x0lsoh-2 */
# .hXKZaE{background:#fff;color:rgba(0,0,0,.35);border-radius:4px;border:1px solid rgb(233,233,233);line-height:60px;font-size:18px;padding-left:17px;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;cursor:text;}
# /* sc-component-id: tvd344-0 */
# .emCoUh{padding:0 60px;}.dWsFia{background:#fff;padding:0 16px;}
# /* sc-component-id: tvd344-1 */
# .jzyqCw{border-top:1px solid rgb(233,233,233);padding:14px 0;}
# /* sc-component-id: sc-1elc1ai-0 */
# .bSDwXy{position:relative;max-width:100%;}
# ...
# /* sc-component-id: sc-463q10-0 */
# .fKMMGn{padding:30px 0 15px;width:100%;background-color:#fff;border-bottom:1px solid rgba(0,0,0,0.15);}
# /* sc-component-id: sc-463q10-1 */
# .bfyZRb{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-width:720px;max-width:1280px;margin:auto;}.fOyuYF{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-width:100%;max-width:px;margin:auto;}
# /* sc-component-id: sc-463q10-5 */
# .guBzwq{height:100px;width:100px;}
# /* sc-component-id: sc-463q10-6 */
# .cJPnXs{margin-top:15px;font-size:24px;line-height:33px;color:rgba(0,0,0,.8);}
# /* sc-component-id: sc-463q10-7 */
# .fXmKmV{font-size:14px;line-height:23px;color:rgba(0,0,0,.45);}
# /* sc-component-id: sc-463q10-10 */
# .eiStmu{margin:8px 0 20px;color:rgba(0,0,0,.35);font-size:14px;}
# /* sc-component-id: sc-463q10-11 */
# .cMLrrf{margin-bottom:20px;}
# /* sc-component-id: sc-1paxri5-0 */
# .eMfEhD{background:#fff;}
# /* sc-component-id: sc-1paxri5-1 */
# .hElmOw{padding-bottom:8px;color:rgba(0,0,0,.35);font-size:14px;}
# /* sc-component-id: sc-1paxri5-2 */
# .eJwxwF{--border-radius:4px;background:#fff;border:1px solid rgb(233,233,233);border-top-width:0;padding:20px;border-top-width:1px;border-radius:var(--border-radius) var(--border-radius) 0 0;border-radius:0 0 var(--border-radius) var(--border-radius);margin-bottom:32px;}.iRuOTU{--border-radius:4px;background:#fff;border:1px solid rgb(233,233,233);border-top-width:0;padding:20px;border-top-width:1px;border-radius:var(--border-radius) var(--border-radius) 0 0;}.ggdXTz{--border-radius:4px;background:#fff;border:1px solid rgb(233,233,233);border-top-width:0;padding:20px;}.hEvkgq{--border-radius:4px;background:#fff;border:1px solid rgb(233,233,233);border-top-width:0;padding:20px;border-radius:0 0 var(--border-radius) var(--border-radius);margin-bottom:32px;}
# /* sc-component-id: sc-6ho0ax-0 */
# .hKtKmf{min-height:100vh;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;padding-top:60px;background-color:rgb(250,250,250);}.hpFJaE{min-height:100vh;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;padding-top:0px;background-color:rgb(250,250,250);}
# /* sc-component-id: sc-6ho0ax-1 */
# .kXGNoo{-webkit-flex:1;-ms-flex:1;flex:1;width:640px;margin:30px auto;}.hnccAe{-webkit-flex:1;-ms-flex:1;flex:1;width:px;width:100%;margin:0px auto;}
# /* sc-component-id: etusys-0 */
# .gBWHDK{display:block;border-radius:30px;height:30px;width:60px;padding:2px;cursor:pointer;background:#3397cf;-webkit-transition:background 0.15s cubic-bezier(.4,0,.2,1);transition:background 0.15s cubic-bezier(.4,0,.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# /* sc-component-id: etusys-1 */
# .cXxqYL{display:none;}
# /* sc-component-id: etusys-2 */
# .feUGZv{display:block;background:#fff;border-radius:100%;height:100%;-webkit-transform:translateX(30px);-ms-transform:translateX(30px);transform:translateX(30px);-webkit-transition:-webkit-transform 0.15s cubic-bezier(.4,0,.2,1);-webkit-transition:transform 0.15s cubic-bezier(.4,0,.2,1);transition:transform 0.15s cubic-bezier(.4,0,.2,1);}
# /* sc-component-id: sc-1nb1ses-0 */
# .kEGeAG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:16px;background-color:#fff;}
# /* sc-component-id: sc-1nb1ses-1 */
# .gPmgHE{-webkit-flex:1;-ms-flex:1;flex:1;}
# /* sc-component-id: sc-1nb1ses-2 */
# .kjHlpT{padding-bottom:0.4em;color:rgba(0,0,0,.8);font-size:24px;}
# /* sc-component-id: sc-1nb1ses-3 */
# .gpEpxy{color:rgba(0,0,0,.6);font-size:15px;line-height:1.5;}
# /* sc-component-id: sc-1nb1ses-4 */
# .gyIZAM{overflow:hidden;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:80px;height:80px;border-radius:4px;}
# /* sc-component-id: sc-1nb1ses-5 */
# .iRctps{display:block;width:100%;}
# /* sc-component-id: sc-1nb1ses-6 */
# .hjhpe{position:relative;display:block;width:100%;padding:16px;border-bottom:1px solid rgba(0,0,0,0.05);background-color:#fff;color:rgba(0,0,0,.6);font-size:17px;}
# /* sc-component-id: sc-1nb1ses-7 */
# .hvsXkS{position:relative;display:block;width:100%;padding:16px;border-bottom:1px solid rgba(0,0,0,0.05);background-color:#fff;color:rgba(0,0,0,.6);font-size:17px;}
# /* sc-component-id: sc-1nb1ses-8 */
# .bquJZI{position:absolute;right:16px;fill:rgba(0,0,0,0.15);}
# /* sc-component-id: sc-1nb1ses-9 */
# .cAydWN{padding:20px 16px;font-size:15px;color:rgba(0,0,0,.35);}
# /* sc-component-id: sc-1nb1ses-10 */
# .gTWIOq{position:relative;display:block;width:100%;padding:16px;border-bottom:1px solid rgba(0,0,0,0.05);background-color:#fff;color:rgba(0,0,0,.6);font-size:17px;margin-top:5px;text-align:center;}
# /* sc-component-id: ie6wvd-0 */
# .gTOADb{height:48px;color:rgba(0,0,0,.35);line-height:48px;}
# /* sc-component-id: ie6wvd-1 */
# .bRXWjo{position:-webkit-sticky;position:sticky;z-index:10;top:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:48px;padding:0 16px;background-color:rgb(250,250,250);box-shadow:rgba(0,0,0,.35) 0 0 1px 0;color:rgba(0,0,0,.35);font-size:15px;} .bRXWjo .ie6wvd-0:not(:last-of-type){margin-right:25px;} .bRXWjo .ie6wvd-0:not(:last-of-type)::after{content:'＞';pointer-events:none;position:absolute;padding:0 5px;}
# /* sc-component-id: sc-1neqvbe-2 */
# .dyvTHC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-height:calc(100vh - 48px);}
# /* sc-component-id: sc-1neqvbe-3 */
# .bwcxoB{-webkit-flex:1;-ms-flex:1;flex:1;width:100%;}
# /* sc-component-id: sc-1wuozkp-0 */
# .uqQgl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:calc(100vh - 60px);width:100%;padding-top:60px;}.dKJRAm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:calc(100vh - 48px);width:100%;padding-top:48px;}
# /* sc-component-id: sc-1wuozkp-1 */
# .jdqKvg{height:100%;max-width:1280px;}.dwkjSE{height:100%;max-width:px;}
# /* sc-component-id: sc-10zd5uv-0 */
# .ixOnNA{height:100%;text-align:center;}
# /* sc-component-id: sc-10zd5uv-1 */
# .kqxqmm{height:250px;margin:auto;}
# /* sc-component-id: sc-10zd5uv-2 */
# .jTWfQM{color:#fff;font-size:32px;line-height:45px;margin-top:0.67em;}
# /* sc-component-id: sc-10zd5uv-3 */
# .cPaQkL{margin:0 0 20px;color:#fff;font-size:24px;line-height:36px;opacity:0.6;}
# /* sc-component-id: sc-10zd5uv-4 */
# .jDLWjZ{font-size:18px;opacity:0.6;padding:2px 16px;}
# /* sc-component-id: sc-16vcadf-0 */
# .kGGRMm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: sc-16vcadf-1 */
# .jvJoGl{-webkit-flex:1;-ms-flex:1;flex:1;overflow:hidden;padding:0 5px;}
# /* sc-component-id: sc-16vcadf-2 */
# .hhgHLW{width:100%;}
# /* sc-component-id: hl8gel-0 */
# .whDXM{width:100%;max-width:1140px;margin:auto;}
# /* sc-component-id: hl8gel-1 */
# .kihvGu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-evenly;-webkit-justify-content:space-evenly;-ms-flex-pack:space-evenly;justify-content:space-evenly;padding:50px 0;}
# /* sc-component-id: hl8gel-2 */
# .cgKQjn{padding-top:80px;} @media (max-width:1024px){.cgKQjn{display:none;}}
# /* sc-component-id: hl8gel-3 */
# .jBMwAb{background:#fff;border-radius:4px;overflow:hidden;width:460px;}
# /* sc-component-id: hl8gel-4 */
# .eIMamf{text-align:center;padding:30px 50px;}
# /* sc-component-id: hl8gel-5 */
# .iuviqQ{margin-bottom:10px;font-size:2em;font-weight:400;line-height:1.6;}
# /* sc-component-id: hl8gel-6 */
# .kduvDr{margin-bottom:30px;display:none;}
# /* sc-component-id: hl8gel-7 */
# .MiOPA{background:#efefef;padding:30px 50px;text-align:center;}
# /* sc-component-id: hl8gel-8 */
# .eHEtcA{color:rgba(0,0,0,.45);margin-bottom:1em;}
# /* sc-component-id: hl8gel-9 */
# .kqXGab{height:auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding-bottom:30px;display:none;} .kqXGab a{color:rgba(0,0,0,.6);font-size:13px;font-weight:bold;margin-right:16px;} .kqXGab a:not(:last-child):after{content:'';margin-left:16px;border-right:1px solid rgba(0,0,0,.6);}
# /* sc-component-id: pi5fkb-0 */
# .bLesBw{height:100vh;width:100%;padding-top:60px;}.gQYhE{height:100vh;width:100%;padding-top:0px;}
# /* sc-component-id: pi5fkb-1 */
# .jodhDq{position:relative;height:100%;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;text-align:center;}
# /* sc-component-id: sc-1gztl72-0 */
# .bAjOdN{padding-top:0;}.hRYhUO{padding-top:24px;}
# /* sc-component-id: gdqyl2-0 */
# .jKryys{text-align:center;line-height:120px;color:rgba(0,0,0,.35);font-size:14px;}
# /* sc-component-id: sc-14g4vr-0 */
# .livlLI{padding:8px 0 0;}.eTdgNs{padding:20px 40px;}
# /* sc-component-id: sc-14g4vr-1 */
# .lbmJpR{background:#fff;}.gIQXxa{background:#fff;border:1px solid rgb(222,222,222);box-shadow:rgba(0,0,0,0.05) 0px 2px 4px 0px;border-radius:4px;}
# /* sc-component-id: sc-14g4vr-2 */
# .fcPtLv{color:rgba(0,0,0,.45);background:#fff;padding:8px 16px;border-bottom:1px solid rgb(233,233,233);}.dHhDUU{color:rgba(0,0,0,.45);padding:20px 20px 5px;}
# /* sc-component-id: cg9ymx-0 */
# .myfFK{padding:16px;}.exsxqP{padding:20px;}
# /* sc-component-id: cg9ymx-1 */
# .oDePp{color:rgba(0,0,0,.95);font-size:18px;}
# /* sc-component-id: cg9ymx-2 */
# .cXsNZq{color:rgba(0,0,0,.6);padding-top:0.8em;}
# /* sc-component-id: cg9ymx-3 */
# .kJntEu{border-bottom:1px solid rgb(222,222,222);margin:0 20px;}
# /* sc-component-id: sc-3y1kdj-0 */
# .bvNEii{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: sc-3y1kdj-1 */
# .dgYUlc{padding-left:20px;}
# /* sc-component-id: sc-8sndv1-0 */
# .cbyecR{padding-top:8px;}.bcJLay{padding-top:0px;}
# /* sc-component-id: kqh8nu-0 */
# .fGEdVE{margin:16px 0 10px;font-size:16px;color:rgba(0,0,0,.8);line-height:1;text-align:start;}
# /* sc-component-id: kqh8nu-1 */
# .cplMLf{margin-top:10px;}
# /* sc-component-id: s6s3mu-0 */
# .bhTAzw > div{width:500px;}
# /* sc-component-id: sc-16fyumm-0 */
# .cCRbUA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;line-height:0;padding:6px;border:none;}
# /* sc-component-id: sc-16fyumm-2 */
# .LWEDC{padding:0 8px;}
# /* sc-component-id: h83273-0 */
# .ibAqsJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background:#fff;border-bottom:1px solid rgb(233,233,233);padding:6px 0;}
# /* sc-component-id: h83273-1 */
# .gpzVtW{padding:0 6px;border-right:1px solid rgb(233,233,233);}
# /* sc-component-id: h83273-2 */
# .fOUKTB{margin-left:auto;padding-right:16px;}
# /* sc-component-id: pies5h-0 */
# .bzlTbL{padding-top:8px;}</style></head><body><div id="__next"><div class="sc-15zy2le-0 bUmARS"><div class="sc-1tl0s6i-0 gRRqRb"><div class="sc-1tl0s6i-1 bkKJCY"><a class="lvor8b-0 jsnIlX" href="/f" title="Dcard"><img alt="Dcard" class="sc-1ywcn7k-0 gYUaPZ" src="/_next/static/images/logo-6c547910a47669647856d4c9cc62f0ba.svg"/></a><div class="sc-15zy2le-1 DLzzZ"><div class="pw4e6a-0 ierzKU"><form><input aria-label="搜尋文章、看板、人物" class="sc-1ag928-0 kUMklR pw4e6a-1 fWARvU" name="query" placeholder="搜尋文章、看板、人物" type="search"/><button class="pw4e6a-2 jMlptb" title="搜尋"><span class="ydgdj7-0 hhSnba pw4e6a-5 etwaaz" fill="#fff" role="img" size="20"><svg viewbox="0 0 28 28"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></span></button><button class="ksi2hf-0 eNbBFe" type="submit"></button></form></div></div></div><div class="sc-1tl0s6i-2 pwVHE" role="navigation"><a class="u7yy6z-0 fnZGBW" href="/signup?redirect=%2Ff" role="button"><span class="u7yy6z-1 fxrSjZ">登入</span></a><div class="sc-1ykc0nb-2 iNRVSl"><a class="u7yy6z-0 deAgGq" role="button" title="更多"><span class="u7yy6z-1 fxrSjZ"><span class="ydgdj7-0 gCQlMD u7yy6z-2 eFRAge" fill="#fff" role="img" size="26"><svg viewbox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></span></a></div></div></div></div><div class="avchkw-0 lcIqKn"><div class="avchkw-1 dLkKRc"><div class="sc-19x83id-0 eqvIEe"><a href="/forum/all"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span class="ydgdj7-0 iYfIzd sc-19x83id-2 eJidNy" fill="#fff" role="img" size="24"><svg viewbox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></span></div><div class="sc-1vptqgj-1 cDavDf">所有看板</div></div></a><a href="/forum/popular"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span class="ydgdj7-0 iYfIzd sc-19x83id-2 eJidNy" fill="#fff" role="img" size="24"><svg viewbox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></span></div><div class="sc-1vptqgj-1 cDavDf">即時熱門看板</div></div></a><a href="/goods"><div class="sc-1yi4rc3-0 btuVdm"><div class="sc-19x83id-1 iqLTew"><span class="ydgdj7-0 iYfIzd sc-5qff8c-0 jcFMFq" fill="#fff" role="img" size="24"><svg viewbox="0 0 24 24"><path d="M8 21a2 2 0 11-2-2 2 2 0 012 2zm10-2a2 2 0 102 2 2 2 0 00-2-2zm2.44-1.19v-1a.5.5 0 00-.5-.5H6.3a.5.5 0 01-.4-.81L7.05 14a1 1 0 00.16-.93L4.48 4.72A1 1 0 004 4.13l-1.85-.9a.5.5 0 00-.67.23l-.48.9a.51.51 0 00.24.64l1.47.71 2.43 7.48-.82 1a2.49 2.49 0 00-.09 2.94 2.62 2.62 0 002.2 1.1h13.5a.51.51 0 00.5-.42zm1.35-7V6.38a2 2 0 00-2-2H9.23A2 2 0 007.3 6.92l1.82 5.8a2 2 0 002.3 1.43l8.74-1.33a2 2 0 001.62-1.97z"></path></svg></span></div><div class="sc-1vptqgj-1 cDavDf">好物研究室</div></div></a><div class="wswqpf-0 ebZjiw ScrollbarsCustom" style="position:relative"><div class="wswqpf-1 IUuAe ScrollbarsCustom-Wrapper" style= ...

# %% [markdown]
# ## Grab + PyQuery

# %%
# !pip install grab
# Out:
# Collecting grab
# Collecting weblib>=0.1.28 (from grab)
# Collecting user-agent (from grab)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from grab) (0.6.0)
# Collecting selection (from grab)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from grab) (1.12.0)
# Requirement already satisfied: pytils in c:\programdata\anaconda3\lib\site-packages (from weblib>=0.1.28->grab) (0.3)
# Installing collected packages: user-agent, weblib, selection, grab
# Successfully installed grab-0.6.41 selection-0.0.14 user-agent-0.1.9 weblib-0.1.30

# %%
# !pip install pyquery
# Out:
# Collecting pyquery
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting cssselect>0.7.9 (from pyquery)
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=2.1 in c:\programdata\anaconda3\lib\site-packages (from pyquery) (4.4.1)
# Installing collected packages: cssselect, pyquery
# Successfully installed cssselect-1.1.0 pyquery-1.4.1

# %%
# '''
# Your Code
# '''
from grab import Grab
from pyquery import PyQuery as pq

g = Grab()
resp = g.go('https://www.dcard.tw/f')

print(resp.body)
# Out:
# b'<!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:400,300"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/images/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/images/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/images/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/images/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/images/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/images/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/images/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/images/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/images/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/images/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/images/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/images/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n      new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n      j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n      \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n      })(window,document,\'script\',\'dataLayer\',\'GTM-TWLTW4M\');</script><meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1"/><meta charSet="utf-8"/><meta name="description" content="\xe5\xbb\xa3\xe5\x8f\x97\xe5\xb9\xb4\xe8\xbc\x95\xe4\xba\xba\xe5\x96\x9c\xe6\x84\x9b\xe7\x9a\x84 Dcard \ ...
